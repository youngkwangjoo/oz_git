# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
browser = webdriver.Chrome()

# %%
# from webdriver_manager.chrome import ChromeDriverManager
# ChromeDriverManager().install()

# %%
url = 'https://www.yes24.com/Product/Category/BestSeller?categoryNumber=001&pageNumber=1&pageSize=24'
browser.get(url)

# %%
#1페이지 링크데이터 수집
browser.find_element(By.CLASS_NAME, 'gd_name').get_attribute('href')
# 1페이지 전체의 링크 데이터
datas = browser.find_elements(By.CLASS_NAME, 'gd_name')

for i in datas:
    print(i.get_attribute('href'))

# %%
 #https://www.yes24.com/Product/Category/BestSeller?categoryNumber=001&pageNumber=1&pageSize=24'
    #https://www.yes24.com/Product/Category/BestSeller?categoryNumber=001&pageNumber=2&pageSize=24'
    #https://www.yes24.com/Product/Category/BestSeller?categoryNumber=001&pageNumber=3&pageSize=24'
# import time

link_list = []
for i in range(1,11):
    print("*" * 10, f"현재{i}페이지 수집중입니다." , "*" * 10)
    url = f'https://www.yes24.com/Product/Category/BestSeller?categoryNumber=001&pageNumber={i}&pageSize=24'
    browser.get(url)
    #1페이지 링크데이터 수집
    browser.find_element(By.CLASS_NAME, 'gd_name').get_attribute('href')
# 1페이지 전체의 링크 데이터
    datas = browser.find_elements(By.CLASS_NAME, 'gd_name')

    for i in datas:
        link = (i.get_attribute('href'))
        link_list.append(link)
    time.sleep(3)

print(link_list)
# Out:
# ********** 현재1페이지 수집중입니다. **********
# ********** 현재2페이지 수집중입니다. **********
# ********** 현재3페이지 수집중입니다. **********
# ********** 현재4페이지 수집중입니다. **********
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[129], line 19
#      17        link = (i.get_attribute('href'))
#      18        link_list.append(link)
# ---> 19    time.sleep(3)
#      21 print(link_list)
#
# KeyboardInterrupt:

# %%
# for link in link_list:
#     browser.get(link)

# browser.get(link_list[0])

# title = browser.find_element(By.CLASS_NAME, 'gd_name').text
# author = browser.find_element(By.CLASS_NAME, 'gd_auth').text
# publisher = browser.find_element(By.CLASS_NAME, 'gd_pub').text
# publishing = browser.find_element(By.CLASS_NAME, 'gd_date').text
# rating = browser.find_element(By.CLASS_NAME, 'yes_b').text
# reviews = browser.find_element(By.CLASS_NAME, 'txC_blue').text
# sales =  browser.find_element(By.CLASS_NAME, 'gd_sellNum').text.split(" ")[2]
# price =  browser.find_element(By.CLASS_NAME, 'yes_m').text[:-1]

# ranking = browser.find_element(By.CLASS_NAME, 'gd_best').text.split(" | ")[0].split(" ")[2][:-1]
# #국내도서 1위
# ranking_weeks = browser.find_element(By.CLASS_NAME, 'gd_best').text.split(" | ")[1].split(" ")[2][:-1]
# #국내도서 탑20 1주
# #국내도서 1위 5주
# #국도서 탑20 1주
#10권정도 보고 포맷 예측한건데 그 이상일경우 어떻게 하지?
#raking에서 문제점은 포맷이 새로들어온 책과 기존에 베스트셀러가 다르다는것... 
#rakingweeks에서 문제점은 1이라는게 단순숫자인데 탑20에서 머문 주간을 표시한다는 정보가 안나타나있어서 주석으로 표시해야할듯
#국내1위 22주
#null값
# Out:
# '1'

# %%
# #데이터 베이스 연동 후 -> 수집한 데이터를 db에 저장(csv)
# #상세페이지 이동 후 데이터 크롤링
# import pymysql
# import time
# import re
# from datetime import datetime

# conn = pymysql.connect(
#     host = 'localhost',
#     user = 'root',
#     password = 'class-password',
#     db = 'yes24',
#     charset = 'utf8mb4',
#     cursorclass = pymysql.cursors.DictCursor
# )

# with conn.cursor() as cur:
#     for i in link_list:
#         browser.get(link)

#         title = browser.find_element(By.CLASS_NAME, 'gd_name').text
#         author = browser.find_element(By.CLASS_NAME, 'gd_auth').text
#         publisher = browser.find_element(By.CLASS_NAME, 'gd_pub').text
#         publishing = browser.find_element(By.CLASS_NAME, 'gd_date').text

#         match = re.search(r'(\d+)년 (\d+)월 (\d+)일', publishing)

#         if match:
#             year, month, day = match.groups()
#             data_obj = datetime(int(year), int(month), int(day))
#             publishing = data_obj.strftime("%Y-%m-%d")
#         else:
#             publishing = "2023-01-01"


#         rating = browser.find_element(By.CLASS_NAME, 'yes_b').text

#         review = browser.find_element(By.CLASS_NAME, 'txC_blue').text
#         review = int(review.replace(",", ""))

#         sales =  browser.find_element(By.CLASS_NAME, 'gd_sellNum').text.split(" ")[2]
#         sales = int(sales.replace(",", ""))

#         price =  browser.find_element(By.CLASS_NAME, 'yes_m').text[:-1]
#         price = int(price.replace(",", ""))

#         full_text =  browser.find_element(By.CLASS_NAME, "gd_best").text
#         parts = full_text.split(" | ")
# #국내도서 탑20 1주
# #국내도서 1위 5주
# #국도서 탑20 1주
# ranking_part여기서 숫자만 추철한게 랭킹
        if len(parts) == 1:
            ranking = 0
            ranking_part = 0
            #|가 없다면 
        else:
            try:

                ranking_part = parts[0]
                ranking = ''.join(filter(str.isdigit, ranking_part))#숫자만
            except:
                ranking = 0

            try:
                # 국내도서 탑20 3주

                ranking_weeks_part = parts[1]
                ranking_weeks = ''.join(filter(str.isdigit, ranking_part.split()[-1]))
            except:
                ranking_weeks = 0 

#         ranking = browser.find_element(By.CLASS_NAME, 'gd_best').text.split(" | ")[0].split(" ")[2][:-1]

#         ranking_weeks = browser.find_element(By.CLASS_NAME, 'gd_best').text.split(" | ")[1].split(" ")[2][:-1]
        
#         sql = """insert into Books(
#                 title, author,  publisher, publishing, rating, review, sales, price, ranking, ranking_weeks
#             )
#             values(
#                 %s, %s, %s ,%s , %s, %s, %s, %s, %s, %s
#             )
#             """
#         cur.execute(sql, (title, author,  publisher, publishing, rating, review, sales, price, ranking, ranking_weeks))
#         conn.commit() 
#         time.sleep(2)

# %%
# 데이터 베이스 연동 후 -> 수집한 데이터를 db에 저장(csv)
# 상세페이지 이동 후 데이터 크롤링
import pymysql
import time
import re
from datetime import datetime
from selenium.webdriver.common.by import By

conn = pymysql.connect(
    host='localhost',
    user='root',
    password='class-password',
    db='yes24',
    charset='utf8mb4',
    cursorclass=pymysql.cursors.DictCursor
)

with conn.cursor() as cur:
    for link in link_list:
        browser.get(link)
        time.sleep(1)

        title = browser.find_element(By.CLASS_NAME, 'gd_name').text
        author = browser.find_element(By.CLASS_NAME, 'gd_auth').text
        publisher = browser.find_element(By.CLASS_NAME, 'gd_pub').text
        publishing = browser.find_element(By.CLASS_NAME, 'gd_date').text

        match = re.search(r'(\d+)년 (\d+)월 (\d+)일', publishing)

        if match:
            year, month, day = match.groups()
            data_obj = datetime(int(year), int(month), int(day))
            publishing = data_obj.strftime("%Y-%m-%d")
        else:
            publishing = "2023-01-01"
        #날짜는 오류 없었음
            
        rating = browser.find_element(By.CLASS_NAME, 'yes_b').text
        try:
            review_text = browser.find_element(By.CLASS_NAME, 'txC_blue').text
            if review_text == '예약판매':
                review = 0
            else:
                review = int(review_text.replace(",", ""))
        except:
            review = 0
        #리뷰가 없거나 예약판매인경우 예외 사항둠


        #정규식으로 바꿔보기
        sales = int(browser.find_element(By.CLASS_NAME, 'gd_sellNum').text.split(" ")[2].replace(",", ""))
        #판매지수 띄어쓰기 때문에 인덱스 값은 2로
        price = int(browser.find_element(By.CLASS_NAME, 'yes_m').text[:-1].replace(",", ""))
        #원단위 빼고
        full_text = browser.find_element(By.CLASS_NAME, "gd_best").text
        #이부분 수정
        arts = full_text.split(" | ")
#국내도서 탑20 1주
#국내도서 1위 5주
#국도서 탑20 1주

        ranking = 0
        ranking_weeks = 0
        #0으로 초기화
        if len(parts) > 1:
            try:
                ranking_part = parts[0]
                ranking = ''.join(filter(str.isdigit, ranking_part))  # 숫자만
            except:
                #프린트 에러메시지를 보통 검
                pass

            try:
                ranking_weeks_part = parts[1]
                ranking_weeks = ''.join(filter(str.isdigit, ranking_weeks_part.split()[-1]))
            except:
                pass
            #이거에 문제점도 같은데 국내도서 순위만 나올경우 그냥 0값으로 매겨버린다. 
            #두번째 문제점은 국내 순위 탑20 몇주 이러면 괜찮은데 뒤에 수험서 자격증 탑 100 6주 이러면 의미가 없는거같아서 차라리 지우는게 나으려나
            #meta table, si 프로젝트, sm 프로젝트 유지보수 프로젝트
        sql = """INSERT INTO Books(
                title, author, publisher, publishing, rating, review, sales, price, ranking, ranking_weeks
            )
            VALUES (
                # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s
            )
            """
        cur.execute(sql, (title, author, publisher, publishing, rating, review, sales, price, ranking, ranking_weeks))
        conn.commit()
        time.sleep(2)  # 다음 페이지 이동 전에 잠시 대기합니다.

#지금은 72건이지만 더 많은경우에 이런 예외처리 하나로는 해결못할거같은데
#타임슬립 줄이기, 3번 돌떄마다 걸기, 10번씩 타임리밋 알아보기, 
#멀티 프로세싱
